# %%
import pandas as pd
import re
import numpy as np

# %%
with open('numerosdeunos.txt', 'r') as file:
    contenido = file.read()

# %%
filas = contenido.split("\n")

# %%
ultimo_elemento=filas[len(filas)-1]
penultimo = filas[len(filas)-2]
ultimo_elemento = filas.pop()
penultimo = filas.pop()

# %%
columnas = [fila.split(",") for fila in filas]

# %%
import csv

with open('archivo.csv', mode='w', newline='') as file:
    writer = csv.writer(file, delimiter=',')
    writer.writerows(columnas)

# %%
mydata = pd.read_csv('archivo.csv')

# %%
x = mydata.iloc[:,1].values
y=mydata.iloc[:,0].values

# %%
x
# Out:
# array([      1,       0,       1, ..., 1048572, 1048573, 1048574])

# %%
y
# Out:
# array([ 1,  0,  1, ..., 18, 19, 19])

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Numero de unos en el universo')
plt.show()

# %%
x_log10 = np.log10(x)
x_log10
# Out:
# <ipython-input-13-be2569c226bb>:1: RuntimeWarning: divide by zero encountered in log10
#   x_log10 = np.log10(x)
# array([0.        ,       -inf, 0.        , ..., 6.02059826, 6.02059867,
#        6.02059908])

# %%
plt.plot(x_log10,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Numero de unos en Log 10')
plt.show()
